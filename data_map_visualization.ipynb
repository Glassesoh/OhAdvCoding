# %% [markdown]
# <a href="https://colab.research.google.com/github/Glassesoh/OhAdvCoding/blob/main/data_map_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install basemap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 860.7/860.7 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 42.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# !pip install basemap-data-hires
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 MB 8.0 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import io
df = pd.read_csv("/content/drive/MyDrive/HydroWASTE_Ukraine_extract.csv")
df.sample(5)
tests=[[50.406160,30.552770],[50.398690,30.492050],[50.428770,30.454410],[50.760270,35.386190],[50.4699751, 30.4725597],[50.45466,30.5238],[50.5003976,30.4533026]]
u=u"""latitude,longitude
48.446071, 37.714359
48.127793, 37.495724
48.870566, 37.631113
47.100120, 38.000115
48.425238, 37.664153
48.871532, 37.764888
48.846551, 38.301663
48.745879, 39.260398
49.455741, 35.135327
47.116521, 37.549347
48.704791, 37.630395
48.812995, 37.561433"""
testdf = pd.read_csv(io.StringIO(u), delimiter=",")
lat2 = testdf['latitude'].values
lon2 = testdf['longitude'].values
testingsites=pd.read_csv("/content/drive/MyDrive/data_waterqual_csv.csv")
lat3=testingsites['LATITUDE'].values
lon3=testingsites['LONGITUDE'].values

# %%
plt.scatter(df['LATITUDE'],df['LONGITUDE'])

# %%
fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='cyl', resolution='h',
            llcrnrlat=47, urcrnrlat=51,
            llcrnrlon=36, urcrnrlon=41, )
m.drawcountries(zorder=1,color="black", linewidth=3)
m.drawcoastlines(color="blue",linewidth=1.2)
m.drawrivers(linewidth=1.2,color="blue")
m.fillcontinents(color='0.8',lake_color='blue')
lat=df['LATITUDE'].values
lon=df['LONGITUDE'].values
water=df['WASTE_DIS'].values
pop=df['POP_SERVED'].values
m.scatter(lon,lat,latlon=True,c=np.log10(water),cmap='Greens',s=pop/1000,alpha=0.5,zorder=999)
m.scatter(lon2,lat2,latlon=True,c='Red',alpha=0.5)
m.scatter(lon3,lat3,latlon=True,c='Blue',alpha=0.5)

for i in range len(df):
  if lat[i]>47 and lat[i]<51:
    if
# Out:
#   File "<ipython-input-7-79a253c1e074>", line 17
#     for i in range len(df):
#                    ^
# SyntaxError: invalid syntax
